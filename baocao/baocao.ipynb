# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2 
import os
from numpy.random import seed
seed(101)
import tensorflow as tf
tf.random.set_seed(101)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
import shutil
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
IMAGE_SIZE = 50   
SAMPLE_SIZE =  60

# %%
 
# %matplotlib inline
 
# Read in the image
image = cv2.imread('D:/HK6/Datamining/project/baocao/dataImage/1/images (16).jpg')
 
# Change color to RGB (from BGR)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
 
plt.imshow(image)

# %%
# Reshaping the image into a 2D array of pixels and 3 color values (RGB)
pixel_vals = image.reshape((-1,3))
 
# Convert to float type
pixel_vals = np.float32(pixel_vals)

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import cv2

image = cv2.imread("D:/HK6/Datamining/project/baocao/dataImage/1/images (15).jpg")
image_lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)

data = image_lab.reshape((-1, 3))
scaler = StandardScaler()
data = scaler.fit_transform(data)

kmeans = KMeans(n_clusters=8)
kmeans.fit(data)
labels = kmeans.labels_

segmented_image = labels.reshape(image_lab.shape[:2])
plt.imshow(segmented_image)
plt.show()
# Out:
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
centers = kmeans.cluster_centers_
centers = scaler.inverse_transform(centers)
centers = centers.reshape((1, -1, 3)).astype(np.uint8)
centers = cv2.cvtColor(centers, cv2.COLOR_LAB2BGR).reshape((-1, 3))

for i, center in enumerate(centers):
    mask = labels.reshape(image.shape[:2]) == i
    mask = mask.astype(np.uint8) * 255

    x, y, w, h = cv2.boundingRect(mask)
    # print(x ,y, w, h)
    # print('w = ', w)
    # print('h = ', h)
    # h = 50
    # w = 50
    # Draw rectangle 
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 1)
    cropImg = image[y: y + h, x : x + w]
    cv2.imwrite("Croped/test"+ str(i) +".png", cropImg)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
method = KMeans(n_clusters=12)
method.fit(data)
labels = method.labels_
method.n_clusters
# Out:
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 12

# %%
os.mkdir("Croped")
os.mkdir("data")
os.mkdir("data/0")
os.mkdir("data/1")

# %%
def deleteImage(folder):
    for file in os.listdir(folder):
        file_path = os.path.join("Croped", file)
        if os.path.isfile(file_path):
            os.remove(file_path)

def resizedImage(pathImage):
    #Read orginal image
    image = cv2.imread(pathImage)

    # Resize image
    resized_image = cv2.resize(image, (50, 50))
    return resized_image

def cropImage(pathImage, method):
    
    # Read image and convert to LAB color
    image = cv2.imread(pathImage)
    image_lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)

    #Standardized data
    data = image_lab.reshape((-1, 3))
    scaler = StandardScaler()
    data = scaler.fit_transform(data)

    method.fit(data)
    labels = method.labels_
    
    for i in range(method.n_clusters):
        mask = labels.reshape(image.shape[:2]) == i
        mask = mask.astype(np.uint8) * 255
        x, y, w, h = cv2.boundingRect(mask)
        cropImg = image[y: y + h, x : x + w]
        cv2.imwrite("Croped/crop"+ str(i) +".png", cropImg)

def minImage(foler_path):

    file_list = os.listdir(foler_path)

    image_files = [file for file in file_list if file.endswith(('.jpg', '.png', "webp"))]

    smallest_size = float('inf')
    smallest_image_path = None

    for image_file in image_files:
        image_path = os.path.join(foler_path, image_file)
        image = cv2.imread(image_path)
        
        height, width, _ = image.shape
        
        if height * width < smallest_size:
            smallest_size = height * width
            smallest_image_path = image_path

    return smallest_image_path

# %%
for img in os.listdir("dataImage/0/"):
    cropImage(os.path.join("dataImage/0/", img), method)
    cv2.imwrite(os.path.join("data/0", img),resizedImage(minImage("Croped")))
    deleteImage("Croped")
# Out:
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
for img in os.listdir("dataImage/1/"):
    cropImage(os.path.join("dataImage/1", img), method)
    cv2.imwrite(os.path.join("data/1", img),resizedImage(minImage("Croped")))
    deleteImage("Croped")
# Out:
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# # Buiding Model

# %%
image_list_0 = os.listdir("data/0")
image_list_1 = os.listdir("data/1")

# %%
image_list_0 = os.listdir("data/0")
image_list_1 = os.listdir("data/1")

data_0 = {
    "image": image_list_0,
    "target": [0] * len(image_list_0)
}

data_1 = {
    "image": image_list_1,
    "target": [1] * len(image_list_1)
}

df_0 = pd.DataFrame(data_0).sample(SAMPLE_SIZE, random_state= 101)
df_1 = pd.DataFrame(data_1).sample(SAMPLE_SIZE, random_state= 101)

df_data = pd.concat([df_0, df_1], axis=0).reset_index(drop=True)

df_data['target'].value_counts()
# Out:
# target
# 0    60
# 1    60
# Name: count, dtype: int64

# %%
df_train, df_val = train_test_split(df_data, test_size=0.2, random_state=101)

print(df_train.shape)
print(df_val.shape)
# Out:
# (96, 2)
# (24, 2)

# %%
base_dir = 'base_dir'
os.mkdir(base_dir)
train_dir = os.path.join(base_dir, 'train_dir')
os.mkdir(train_dir)

val_dir = os.path.join(base_dir, 'val_dir')
os.mkdir(val_dir)

no_cancer = os.path.join(train_dir, '0')
os.mkdir(no_cancer)
cancer = os.path.join(train_dir, '1')
os.mkdir(cancer)

no_cancer = os.path.join(val_dir, '0')
os.mkdir(no_cancer)
cancer = os.path.join(val_dir, '1')
os.mkdir(cancer)

# %%
df_data.set_index('image', inplace=True)
train_list = list(df_train['image'])
val_list = list(df_val['image'])

# %%
for image in train_list:
    fname = image
    target = df_data.loc[image,'target']
    src = os.path.join("data", str(target), fname)
    dst = os.path.join(train_dir, str(target), fname)
    shutil.move(src, dst)

# %%
for image in val_list:
    fname = image
    target = df_data.loc[image,'target']
    src = os.path.join("data", str(target), fname)
    dst = os.path.join(val_dir, str(target), fname)
    shutil.move(src, dst)

# %%
train_path = "base_dir/train_dir"
valid_path = "base_dir/val_dir"


num_train_samples = len(df_train)
num_val_samples = len(df_val)
train_batch_size = 10
val_batch_size = 10


train_steps = np.ceil(num_train_samples / train_batch_size)
val_steps = np.ceil(num_val_samples / val_batch_size)

# %%
datagen = ImageDataGenerator(rescale=1.0/255)

train_gen = datagen.flow_from_directory(train_path,
                                        target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                        batch_size=train_batch_size,
                                        class_mode='categorical')

val_gen = datagen.flow_from_directory(valid_path,
                                        target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                        batch_size=val_batch_size,
                                        class_mode='categorical')


test_gen = datagen.flow_from_directory(valid_path,
                                        target_size=(IMAGE_SIZE,IMAGE_SIZE),
                                        batch_size=1,
                                        class_mode='categorical')
# Out:
# Found 96 images belonging to 2 classes.
# Found 24 images belonging to 2 classes.
# Found 24 images belonging to 2 classes.

# %%
kernel_size = (3,3)
pool_size= (2,2)
first_filters = 32
second_filters = 64
third_filters = 128

dropout_conv = 0.3
dropout_dense = 0.3


model = Sequential()
model.add(Conv2D(first_filters, kernel_size, activation = 'relu', 
                 input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3)))
model.add(MaxPooling2D(pool_size = pool_size)) 
model.add(Dropout(dropout_conv))

model.add(Conv2D(second_filters, kernel_size, activation ='relu'))
model.add(MaxPooling2D(pool_size = pool_size))
model.add(Dropout(dropout_conv))

model.add(Conv2D(third_filters, kernel_size, activation ='relu'))
model.add(MaxPooling2D(pool_size = pool_size))
model.add(Dropout(dropout_conv))

model.add(Flatten())
model.add(Dense(256, activation = "relu"))
model.add(Dropout(dropout_dense))
model.add(Dense(2, activation = "softmax"))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 48, 48, 32)        896
#
#  max_pooling2d_3 (MaxPooling  (None, 24, 24, 32)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 24, 24, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 22, 22, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 11, 11, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 11, 11, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 9, 9, 128)         73856
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_6 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 256)               524544
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 618,306
# Trainable params: 618,306
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
filepath = "model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, 
                             save_best_only=True, mode='max')

reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, 
                                   verbose=1, mode='max', min_lr=0.00001)
                              
                              
callbacks_list = [checkpoint, reduce_lr]

history = model.fit(train_gen, steps_per_epoch=train_steps, 
                    validation_data=val_gen,
                    validation_steps=val_steps,
                    epochs=60, verbose=1,
                   callbacks=callbacks_list)
# Out:
# Epoch 1/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.7179 - accuracy: 0.4535
# Epoch 1: val_accuracy improved from -inf to 0.58333, saving model to model.h5
# 10/10 [==============================] - 2s 105ms/step - loss: 0.7160 - accuracy: 0.4688 - val_loss: 0.6929 - val_accuracy: 0.5833 - lr: 1.0000e-04
# Epoch 2/60
# 10/10 [==============================] - ETA: 0s - loss: 0.7044 - accuracy: 0.5000
# Epoch 2: val_accuracy did not improve from 0.58333
# 10/10 [==============================] - 1s 55ms/step - loss: 0.7044 - accuracy: 0.5000 - val_loss: 0.6923 - val_accuracy: 0.5833 - lr: 1.0000e-04
# Epoch 3/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6858 - accuracy: 0.5233
# Epoch 3: val_accuracy did not improve from 0.58333
# 10/10 [==============================] - 1s 56ms/step - loss: 0.6889 - accuracy: 0.5208 - val_loss: 0.6923 - val_accuracy: 0.5833 - lr: 1.0000e-04
# Epoch 4/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6966 - accuracy: 0.5000
# Epoch 4: val_accuracy did not improve from 0.58333
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 10/10 [==============================] - 1s 57ms/step - loss: 0.6945 - accuracy: 0.5208 - val_loss: 0.6919 - val_accuracy: 0.5833 - lr: 1.0000e-04
# Epoch 5/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.7019 - accuracy: 0.5116
# Epoch 5: val_accuracy did not improve from 0.58333
# 10/10 [==============================] - 1s 55ms/step - loss: 0.6991 - accuracy: 0.5208 - val_loss: 0.6918 - val_accuracy: 0.5000 - lr: 5.0000e-05
# Epoch 6/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6871 - accuracy: 0.5233
# Epoch 6: val_accuracy did not improve from 0.58333
# 10/10 [==============================] - 1s 56ms/step - loss: 0.6961 - accuracy: 0.4688 - val_loss: 0.6919 - val_accuracy: 0.5000 - lr: 5.0000e-05
# Epoch 7/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6952 - accuracy: 0.5349
# Epoch 7: val_accuracy did not improve from 0.58333
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 10/10 [==============================] - 1s 56ms/step - loss: 0.6966 - accuracy: 0.5417 - val_loss: 0.6917 - val_accuracy: 0.5833 - lr: 5.0000e-05
# Epoch 8/60
# 10/10 [==============================] - ETA: 0s - loss: 0.7083 - accuracy: 0.4271
# Epoch 8: val_accuracy did not improve from 0.58333
# 10/10 [==============================] - 1s 58ms/step - loss: 0.7083 - accuracy: 0.4271 - val_loss: 0.6918 - val_accuracy: 0.5417 - lr: 2.5000e-05
# Epoch 9/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6969 - accuracy: 0.5104
# Epoch 9: val_accuracy did not improve from 0.58333
# 10/10 [==============================] - 1s 57ms/step - loss: 0.6969 - accuracy: 0.5104 - val_loss: 0.6918 - val_accuracy: 0.5833 - lr: 2.5000e-05
# Epoch 10/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6771 - accuracy: 0.5833
# Epoch 10: val_accuracy did not improve from 0.58333
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 10/10 [==============================] - 1s 55ms/step - loss: 0.6771 - accuracy: 0.5833 - val_loss: 0.6919 - val_accuracy: 0.5833 - lr: 2.5000e-05
# Epoch 11/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6874 - accuracy: 0.5698
# Epoch 11: val_accuracy did not improve from 0.58333
# 10/10 [==============================] - 1s 57ms/step - loss: 0.6870 - accuracy: 0.5625 - val_loss: 0.6919 - val_accuracy: 0.5833 - lr: 1.2500e-05
# Epoch 12/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6974 - accuracy: 0.5104
# Epoch 12: val_accuracy did not improve from 0.58333
# 10/10 [==============================] - 1s 56ms/step - loss: 0.6974 - accuracy: 0.5104 - val_loss: 0.6920 - val_accuracy: 0.5833 - lr: 1.2500e-05
# Epoch 13/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6875 - accuracy: 0.5625
# Epoch 13: val_accuracy did not improve from 0.58333
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1e-05.
# 10/10 [==============================] - 1s 58ms/step - loss: 0.6875 - accuracy: 0.5625 - val_loss: 0.6920 - val_accuracy: 0.5833 - lr: 1.2500e-05
# Epoch 14/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6870 - accuracy: 0.6047
# Epoch 14: val_accuracy improved from 0.58333 to 0.62500, saving model to model.h5
# 10/10 [==============================] - 1s 69ms/step - loss: 0.6917 - accuracy: 0.5833 - val_loss: 0.6919 - val_accuracy: 0.6250 - lr: 1.0000e-05
# Epoch 15/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6893 - accuracy: 0.5333
# Epoch 15: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 55ms/step - loss: 0.6861 - accuracy: 0.5521 - val_loss: 0.6919 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 16/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6954 - accuracy: 0.5465
# Epoch 16: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 55ms/step - loss: 0.6961 - accuracy: 0.5312 - val_loss: 0.6919 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 17/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6962 - accuracy: 0.5625
# Epoch 17: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 54ms/step - loss: 0.6962 - accuracy: 0.5625 - val_loss: 0.6919 - val_accuracy: 0.6250 - lr: 1.0000e-05
# Epoch 18/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6900 - accuracy: 0.5116
# Epoch 18: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 56ms/step - loss: 0.6881 - accuracy: 0.5208 - val_loss: 0.6919 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 19/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6915 - accuracy: 0.5465
# Epoch 19: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 55ms/step - loss: 0.6927 - accuracy: 0.5521 - val_loss: 0.6919 - val_accuracy: 0.6250 - lr: 1.0000e-05
# Epoch 20/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6934 - accuracy: 0.5349
# Epoch 20: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 55ms/step - loss: 0.6951 - accuracy: 0.5104 - val_loss: 0.6920 - val_accuracy: 0.6250 - lr: 1.0000e-05
# Epoch 21/60
# 10/10 [==============================] - ETA: 0s - loss: 0.7043 - accuracy: 0.5417
# Epoch 21: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 64ms/step - loss: 0.7043 - accuracy: 0.5417 - val_loss: 0.6920 - val_accuracy: 0.6250 - lr: 1.0000e-05
# Epoch 22/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6918 - accuracy: 0.5465
# Epoch 22: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 53ms/step - loss: 0.6906 - accuracy: 0.5417 - val_loss: 0.6920 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 23/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6833 - accuracy: 0.5312
# Epoch 23: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 58ms/step - loss: 0.6833 - accuracy: 0.5312 - val_loss: 0.6920 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 24/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.5417
# Epoch 24: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 54ms/step - loss: 0.6935 - accuracy: 0.5417 - val_loss: 0.6920 - val_accuracy: 0.6250 - lr: 1.0000e-05
# Epoch 25/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6902 - accuracy: 0.5000
# Epoch 25: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 56ms/step - loss: 0.6900 - accuracy: 0.4896 - val_loss: 0.6920 - val_accuracy: 0.6250 - lr: 1.0000e-05
# Epoch 26/60
# 10/10 [==============================] - ETA: 0s - loss: 0.7028 - accuracy: 0.5104
# Epoch 26: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 56ms/step - loss: 0.7028 - accuracy: 0.5104 - val_loss: 0.6920 - val_accuracy: 0.6250 - lr: 1.0000e-05
# Epoch 27/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6994 - accuracy: 0.5116
# Epoch 27: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 54ms/step - loss: 0.6960 - accuracy: 0.5208 - val_loss: 0.6920 - val_accuracy: 0.6250 - lr: 1.0000e-05
# Epoch 28/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6918 - accuracy: 0.5698
# Epoch 28: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 56ms/step - loss: 0.6942 - accuracy: 0.5417 - val_loss: 0.6920 - val_accuracy: 0.6250 - lr: 1.0000e-05
# Epoch 29/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.7021 - accuracy: 0.5000
# Epoch 29: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 55ms/step - loss: 0.7012 - accuracy: 0.5104 - val_loss: 0.6920 - val_accuracy: 0.6250 - lr: 1.0000e-05
# Epoch 30/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6870 - accuracy: 0.5667
# Epoch 30: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 56ms/step - loss: 0.6865 - accuracy: 0.5729 - val_loss: 0.6920 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 31/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6830 - accuracy: 0.5930
# Epoch 31: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 55ms/step - loss: 0.6819 - accuracy: 0.5938 - val_loss: 0.6920 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 32/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5625
# Epoch 32: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 55ms/step - loss: 0.6933 - accuracy: 0.5625 - val_loss: 0.6920 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 33/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6849 - accuracy: 0.5233
# Epoch 33: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 55ms/step - loss: 0.6860 - accuracy: 0.5312 - val_loss: 0.6920 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 34/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6714 - accuracy: 0.6744
# Epoch 34: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 55ms/step - loss: 0.6729 - accuracy: 0.6771 - val_loss: 0.6920 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 35/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6869 - accuracy: 0.6250
# Epoch 35: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 55ms/step - loss: 0.6869 - accuracy: 0.6250 - val_loss: 0.6920 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 36/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6827 - accuracy: 0.5698
# Epoch 36: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 54ms/step - loss: 0.6832 - accuracy: 0.5625 - val_loss: 0.6921 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 37/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6817 - accuracy: 0.6047
# Epoch 37: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 64ms/step - loss: 0.6807 - accuracy: 0.6146 - val_loss: 0.6921 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 38/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6933 - accuracy: 0.5208
# Epoch 38: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 55ms/step - loss: 0.6933 - accuracy: 0.5208 - val_loss: 0.6920 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 39/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6916 - accuracy: 0.5833
# Epoch 39: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 56ms/step - loss: 0.6916 - accuracy: 0.5833 - val_loss: 0.6920 - val_accuracy: 0.6250 - lr: 1.0000e-05
# Epoch 40/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6901 - accuracy: 0.5312
# Epoch 40: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 55ms/step - loss: 0.6901 - accuracy: 0.5312 - val_loss: 0.6920 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 41/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5104
# Epoch 41: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 57ms/step - loss: 0.6929 - accuracy: 0.5104 - val_loss: 0.6920 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 42/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6950 - accuracy: 0.4651
# Epoch 42: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 58ms/step - loss: 0.6891 - accuracy: 0.5000 - val_loss: 0.6919 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 43/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6999 - accuracy: 0.4535
# Epoch 43: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 54ms/step - loss: 0.6946 - accuracy: 0.5000 - val_loss: 0.6919 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 44/60
# 10/10 [==============================] - ETA: 0s - loss: 0.7014 - accuracy: 0.5312
# Epoch 44: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 56ms/step - loss: 0.7014 - accuracy: 0.5312 - val_loss: 0.6919 - val_accuracy: 0.5417 - lr: 1.0000e-05
# Epoch 45/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6982 - accuracy: 0.5000
# Epoch 45: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 54ms/step - loss: 0.6951 - accuracy: 0.5312 - val_loss: 0.6920 - val_accuracy: 0.5417 - lr: 1.0000e-05
# Epoch 46/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6833 - accuracy: 0.5104
# Epoch 46: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 55ms/step - loss: 0.6833 - accuracy: 0.5104 - val_loss: 0.6920 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 47/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6891 - accuracy: 0.5729
# Epoch 47: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 56ms/step - loss: 0.6891 - accuracy: 0.5729 - val_loss: 0.6920 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 48/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6790 - accuracy: 0.5729
# Epoch 48: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 56ms/step - loss: 0.6790 - accuracy: 0.5729 - val_loss: 0.6921 - val_accuracy: 0.5417 - lr: 1.0000e-05
# Epoch 49/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6868 - accuracy: 0.5930
# Epoch 49: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 65ms/step - loss: 0.6873 - accuracy: 0.5833 - val_loss: 0.6921 - val_accuracy: 0.5417 - lr: 1.0000e-05
# Epoch 50/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6838 - accuracy: 0.5814
# Epoch 50: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 55ms/step - loss: 0.6863 - accuracy: 0.5521 - val_loss: 0.6921 - val_accuracy: 0.5417 - lr: 1.0000e-05
# Epoch 51/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6822 - accuracy: 0.5938
# Epoch 51: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 55ms/step - loss: 0.6822 - accuracy: 0.5938 - val_loss: 0.6921 - val_accuracy: 0.5417 - lr: 1.0000e-05
# Epoch 52/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6935 - accuracy: 0.5349
# Epoch 52: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 54ms/step - loss: 0.6945 - accuracy: 0.5208 - val_loss: 0.6922 - val_accuracy: 0.5417 - lr: 1.0000e-05
# Epoch 53/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6957 - accuracy: 0.5116
# Epoch 53: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 53ms/step - loss: 0.6975 - accuracy: 0.5104 - val_loss: 0.6922 - val_accuracy: 0.5417 - lr: 1.0000e-05
# Epoch 54/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6762 - accuracy: 0.6146
# Epoch 54: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 57ms/step - loss: 0.6762 - accuracy: 0.6146 - val_loss: 0.6921 - val_accuracy: 0.5417 - lr: 1.0000e-05
# Epoch 55/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6881 - accuracy: 0.5222
# Epoch 55: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 53ms/step - loss: 0.6904 - accuracy: 0.5208 - val_loss: 0.6921 - val_accuracy: 0.5417 - lr: 1.0000e-05
# Epoch 56/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6800 - accuracy: 0.5930
# Epoch 56: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 56ms/step - loss: 0.6763 - accuracy: 0.6042 - val_loss: 0.6921 - val_accuracy: 0.5417 - lr: 1.0000e-05
# Epoch 57/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6851 - accuracy: 0.6042
# Epoch 57: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 55ms/step - loss: 0.6851 - accuracy: 0.6042 - val_loss: 0.6921 - val_accuracy: 0.5833 - lr: 1.0000e-05
# Epoch 58/60
# 10/10 [==============================] - ETA: 0s - loss: 0.6900 - accuracy: 0.5938
# Epoch 58: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 56ms/step - loss: 0.6900 - accuracy: 0.5938 - val_loss: 0.6921 - val_accuracy: 0.5417 - lr: 1.0000e-05
# Epoch 59/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6841 - accuracy: 0.5581
# Epoch 59: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 56ms/step - loss: 0.6845 - accuracy: 0.5417 - val_loss: 0.6921 - val_accuracy: 0.5417 - lr: 1.0000e-05
# Epoch 60/60
#  9/10 [==========================>...] - ETA: 0s - loss: 0.6872 - accuracy: 0.5233
# Epoch 60: val_accuracy did not improve from 0.62500
# 10/10 [==============================] - 1s 54ms/step - loss: 0.6873 - accuracy: 0.5312 - val_loss: 0.6921 - val_accuracy: 0.5833 - lr: 1.0000e-05

# %%
model.save("model.h5", include_optimizer=True)
model.load_weights("model.h5")
val_loss, val_accuracy = model.evaluate(test_gen,  steps=len(df_val))

print('val_loss:', val_loss)
print('val_acc:', val_accuracy)
# Out:
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6921 - accuracy: 0.5833
# val_loss: 0.6921200156211853
# val_acc: 0.5833333134651184

# %%
shutil.rmtree("base_dir")
shutil.rmtree("Croped")
shutil.rmtree("data")
